# %% [markdown]
# # Chennai

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
from selenium.common.exceptions import NoSuchElementException

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
options = Options()
options.binary_location = "C:\Program Files\Google\Chrome Beta\Application\chrome.exe"
driver = webdriver.Chrome(chrome_options=options, executable_path="chromedriver.exe", )

# %%
# getting to the url
driver.get("https://www.cars24.com/buy-used-car?sort=HL&storeCityId=5732&pinId=600001")
time.sleep(5)
# Allow 2 seconds for the web page to open
scroll_pause_time = 1 # You can set your own pause time. My laptop is a bit slow so I use 1 sec
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
history=[]
owner=[]
kilometers=[]
fuel=[]
last_service=[]
transmission=[]
registration=[]
insurance_type=[]
insurance_validity=[]
year=[]
brand=[]
model=[]
location=[]

# %%
u=driver.find_elements_by_xpath("//div[@class='col-4']/a")

url = []
for i in u:
    url.append(i.get_attribute("href"))              

len(url)
# Out:
# 550

# %%
price=[]
p=driver.find_elements_by_xpath("//div[@class='_19zc5']")
for pp in p:
    price.append(pp.text.split("\n")[1].replace("₹",""))
    
len(price)
# Out:
# 550

# %%
for ii in url:
    
    driver.get(ii)
    time.sleep(2)
    row=driver.find_elements_by_xpath("//strong[@class='_1-PH2']")
    name=driver.find_element_by_xpath("//h2[@class='_2geSF']")
    loc=driver.find_element_by_xpath("//p[@class='_1V4-O']").text
    history.append(row[0].text)
    owner.append(row[1].text)
    kilometers.append(row[2].text.replace("km","").strip())
    fuel.append(row[3].text)
    last_service.append(row[4].text.split("km")[1].replace("(","").replace(")","").strip())
    transmission.append(row[5].text)
    registration.append(row[6].text)
    insurance_type.append(row[7].text.split("\n")[1])
    insurance_validity.append((row[7].text.split("\n")[0]).replace("Valid upto","").strip())
    year.append(row[8].text)
    brand.append(name.text.split(" ")[1])
    model.append(" ".join(name.text.split(" ")[2:]))
    location.append(loc)

# %%
df=pd.DataFrame()
df["history"] = history
df["owner"] = owner
df["kilometers"] = kilometers
df["fuel"] = fuel
df["last_service"] = last_service
df["transmission"] = transmission
df["registration"] = registration
df["insurance_type"] = insurance_type
df["insurance_validity"] = insurance_validity
df["year"] = year
df["brand"] = brand
df["model"] = model
df["location"] = location
df["url"] = url
df["price"] = price

# %%
df
# Out:
#             history      owner kilometers    fuel last_service transmission  \
# 0    Non-Accidental  1st Owner     18,527  Diesel  23 Jun 2022    AUTOMATIC
# 1    Non-Accidental  1st Owner     34,502  Diesel  24 Jun 2022       MANUAL
# 2    Non-Accidental  1st Owner     25,480  Petrol  29 Jun 2022    AUTOMATIC
# 3    Non-Accidental  1st Owner      3,422  Diesel  05 Jul 2022       MANUAL
# 4    Non-Accidental  1st Owner     80,287  Petrol  21 Jun 2022    AUTOMATIC
# 5    Non-Accidental  1st Owner     34,649  Diesel  24 Jun 2022       MANUAL
# 6    Non-Accidental  1st Owner     24,939  Petrol  03 Jul 2022    AUTOMATIC
# 7    Non-Accidental  1st Owner      8,950  Petrol  23 Jun 2022    AUTOMATIC
# 8    Non-Accidental  1st Owner     46,581  Diesel  04 Jul 2022       MANUAL
# 9    Non-Accidental  1st Owner     14,736  Diesel  22 Jun 2022       MANUAL
# 10   Non-Accidental  1st Owner      7,472  Petrol  24 Jun 2022       MANUAL
# ...

# %%
df.to_csv("Chennai_cars.csv")

# %% [markdown]
# # Mumbai

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
from selenium.common.exceptions import NoSuchElementException

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
options = Options()
options.binary_location = "C:\Program Files\Google\Chrome Beta\Application\chrome.exe"
driver = webdriver.Chrome(chrome_options=options, executable_path="chromedriver.exe", )

# %%
# getting to the url
driver.get("https://www.cars24.com/buy-used-car?sort=HL&storeCityId=2378&pinId=400001")
time.sleep(5)
# Allow 2 seconds for the web page to open
scroll_pause_time = 2 # You can set your own pause time. My laptop is a bit slow so I use 1 sec
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

history=[]
owner=[]
kilometers=[]
fuel=[]
last_service=[]
transmission=[]
registration=[]
insurance_type=[]
insurance_validity=[]
year=[]
brand=[]
model=[]
location=[]

# %%
u=driver.find_elements_by_xpath("//div[@class='col-4']/a")

url = []
for i in u:
    url.append(i.get_attribute("href"))              

len(url)
# Out:
# 598

# %%
price=[]
p=driver.find_elements_by_xpath("//div[@class='_19zc5']")
for pp in p:
    price.append(pp.text.split("\n")[1].replace("₹",""))
    
len(price)
# Out:
# 598

# %%
for ii in url:
    
    driver.get(ii)
    time.sleep(1.5)
    row=driver.find_elements_by_xpath("//strong[@class='_1-PH2']")
    name=driver.find_element_by_xpath("//h2[@class='_2geSF']")
    loc=driver.find_element_by_xpath("//p[@class='_1V4-O']").text
    history.append(row[0].text)
    owner.append(row[1].text)
    kilometers.append(row[2].text.replace("km","").strip())
    fuel.append(row[3].text)
    last_service.append(row[4].text.split("km")[1].replace("(","").replace(")","").strip())
    transmission.append(row[5].text)
    registration.append(row[6].text)
    insurance_type.append(row[7].text.split("\n")[1])
    insurance_validity.append((row[7].text.split("\n")[0]).replace("Valid upto","").strip())
    year.append(row[8].text)
    brand.append(name.text.split(" ")[1])
    model.append(" ".join(name.text.split(" ")[2:]))
    location.append(loc)

# %%
df=pd.DataFrame()
df["history"] = history
df["owner"] = owner
df["kilometers"] = kilometers
df["fuel"] = fuel
df["last_service"] = last_service
df["transmission"] = transmission
df["registration"] = registration
df["insurance_type"] = insurance_type
df["insurance_validity"] = insurance_validity
df["year"] = year
df["brand"] = brand
df["model"] = model
df["location"] = location
df["url"] = url
df["price"] = price

# %%
df.to_csv("Mumbai_cars.csv")

# %% [markdown]
# # Now i am going to use different city links on same Code

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
from selenium.common.exceptions import NoSuchElementException
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
options = Options()
options.binary_location = "C:\Program Files\Google\Chrome Beta\Application\chrome.exe"
driver = webdriver.Chrome(chrome_options=options, executable_path="chromedriver.exe", )

# %%
# getting to the url
driver.get("https://www.cars24.com/buy-used-car?sort=HL&storeCityId=2713&pinId=440001")
time.sleep(5)
# Allow 2 seconds for the web page to open
scroll_pause_time = 4 # You can set your own pause time. My laptop is a bit slow so I use 1 sec
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

history=[]
owner=[]
kilometers=[]
fuel=[]
last_service=[]
transmission=[]
registration=[]
insurance_type=[]
insurance_validity=[]
year=[]
brand=[]
model=[]
location=[]

# %%
u=driver.find_elements_by_xpath("//div[@class='col-4']/a")

url = []
for i in u:
    url.append(i.get_attribute("href"))              

len(url)
# Out:
# 78

# %%
price=[]
p=driver.find_elements_by_xpath("//div[@class='_19zc5']")
for pp in p:
    price.append(pp.text.split("\n")[1].replace("₹",""))
    
len(price)
# Out:
# 78

# %%
for ii in url:
    
    driver.get(ii)
    time.sleep(0.5)
    row=driver.find_elements_by_xpath("//strong[@class='_1-PH2']")
    if len(row)==9:
        
        name=driver.find_element_by_xpath("//h2[@class='_2geSF']")
        loc=driver.find_element_by_xpath("//p[@class='_1V4-O']").text
        history.append(row[0].text)
        owner.append(row[1].text)
        kilometers.append(row[2].text.replace("km","").strip())
        fuel.append(row[3].text)
        last_service.append(row[4].text.split("km")[1].replace("(","").replace(")","").strip())
        transmission.append(row[5].text)
        registration.append(row[6].text)
        insurance_type.append(row[7].text.split("\n")[1])
        insurance_validity.append((row[7].text.split("\n")[0]).replace("Valid upto","").strip())
        year.append(row[8].text)
        brand.append(name.text.split(" ")[1])
        model.append(" ".join(name.text.split(" ")[2:]))
        location.append(loc)
        
        
    else:
        name=driver.find_element_by_xpath("//h2[@class='_2geSF']")
        loc=driver.find_element_by_xpath("//p[@class='_1V4-O']").text
        history.append(np.nan)
        owner.append(np.nan)
        kilometers.append(np.nan)
        fuel.append(np.nan)
        last_service.append(np.nan)
        transmission.append(np.nan)
        registration.append(np.nan)
        insurance_type.append(np.nan)
        insurance_validity.append(np.nan)
        year.append(np.nan)
        brand.append(np.nan)
        model.append(np.nan)
        location.append(loc)

# %%
df=pd.DataFrame()
df["history"] = history
df["owner"] = owner
df["kilometers"] = kilometers
df["fuel"] = fuel
df["last_service"] = last_service
df["transmission"] = transmission
df["registration"] = registration
df["insurance_type"] = insurance_type
df["insurance_validity"] = insurance_validity
df["year"] = year
df["brand"] = brand
df["model"] = model
df["location"] = location
df["url"] = url
df["price"] = price

# %%
df.to_csv("Nagpur_cars.csv")

# %%
df
# Out:
#            history      owner kilometers          fuel last_service  \
# 0   Non-Accidental  1st Owner     28,904        Petrol  28 Jun 2022
# 1   Non-Accidental  2nd Owner     22,073        Petrol  28 Jun 2022
# 2   Non-Accidental  2nd Owner     43,822        Diesel  01 Jul 2022
# 3   Non-Accidental  1st Owner     19,648        Diesel  01 Jul 2022
# 4   Non-Accidental  1st Owner     24,811        Petrol  07 Jul 2022
# 5   Non-Accidental  1st Owner     56,035        Diesel  26 Jun 2022
# 6   Non-Accidental  1st Owner     76,751        Diesel  05 Jul 2022
# 7   Non-Accidental  1st Owner     28,125        Petrol  05 Jul 2022
# 8   Non-Accidental  1st Owner     54,083        Diesel  25 Jun 2022
# 9   Non-Accidental  1st Owner     44,929        Diesel  30 Jun 2022
# 10  Non-Accidental  1st Owner     50,196        Diesel  01 Jul 2022
# 11  Non-Accidental  1st Owner      5,937        Petrol  05 Jul 2022
# 12  Non-Accidental  1st Owner      6,552        Petrol  04 Jul 2022
# ...
