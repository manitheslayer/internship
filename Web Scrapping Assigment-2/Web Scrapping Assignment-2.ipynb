# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# %%
# initating the chromedriver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# %%
# getting to the url
driver.get("https://www.naukri.com/")

# %%
# finding the designation field by absolute xpath
designation = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[1]/div/div/div/input")
# sending the string Data analyst to designaiton field
designation.send_keys("Data analyst")
# finding the location element by absolute xpath
location = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input")
# sending the string Banglore to the location field
location.send_keys("Bangalore")

# %%
# finding the Search button by Absolute x path
search = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search.click()

# %%
# implicit wait for loading the webpage
time.sleep(2)

# %%
# creating a empty list for all titles to be scrapped
company_name=[]
job_title = []
job_location=[]
experience_required=[]

# %%
# i have planned to scrap 5 pages so i initated while loop
k=0
while k <= 4:
    # finding  elements by  x path functions
    cn = driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
    jt = driver.find_elements_by_xpath("//div[@class='info fleft']/a[1]")
    jl = driver.find_elements_by_xpath("//li[@class = 'fleft grey-text br2 placeHolderLi location']/span[1]")
    er = driver.find_elements_by_xpath("//li[@class = 'fleft grey-text br2 placeHolderLi experience']/span[1]")
    # here i found the next page button by x path functions 
    a = driver.find_element_by_xpath("/html/body/div/div[3]/div[2]/section[2]/div[3]/div/a[2]")
    
    # using for loop to get stored data and extracting text from it
    for i in cn:
        company_name.append(i.text)
        
        
    for j in jt:
        job_title.append(j.text)  
    
    
    
    for l in jl:
        job_location.append(l.text)
        
        
    for m in er:
        experience_required.append(m.text) 
            
    # finally i am simulating a click on next page and whole loop continues again      
    a.click()
    time.sleep(2)
    k +=1

# %%
print(f'the company name scrapped are {len(company_name)},the job title scrapped are {len(job_title)},the job locaiton scrapped are {len(job_location)},the experience required scrapped are {len(experience_required)}')
# Out:
# the company name scrapped are 100,the job title scrapped are 100,the job locaiton scrapped are 100,the experience required scrapped are 100

# %%
# storing in data frame
df = pd.DataFrame()
df["Company Name"]=company_name
df["Job Title"] = job_title
df["Job Location"]=job_location
df["Experience Required"] = experience_required
df
# Out:
#                                   Company Name  \
# 0                                      Siemens
# 1                                      Walmart
# 2          Avanze Technologies India Pvt. Ltd.
# 3   FINNOVATION TECH SOLUTIONS PRIVATE LIMITED
# 4       TALENT MAX HR & MANAGEMENT CONSULTANTS
# ..                                         ...
# 95                             Western Digital
# 96              TM Inputs & Services Pvt. Ltd.
# 97                                       Gojek
# 98                                        DOCS
# 99                                        DOCS
#
#                                             Job Title  \
# 0                     Sr Domain Expert -Data Analysts
# 1                                 Senior Data Analyst
# 2                Data Analysts with Business Analysis
# 3                                 Senior Data Analyst
# 4                        Data Analyst / Data Engineer
# ..                                                ...
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# initating the chrome driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# getting the url
driver.get("https://www.naukri.com/")

# finding the designation field by absolute xpath
designation = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[1]/div/div/div/input")
# sending the string Data analyst to designaiton field
designation.send_keys("Data Scientist")
# finding the location element by absolute xpath
location = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input")
# sending the string Banglore to the location field
location.send_keys("Bangalore")

# finding the Search button by Absolute x path
search = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search.click()

# implicit wait for loading the webpage
time.sleep(2)

# creating a empty list for all titles to be scrapped
company_name=[]
job_title = []
job_location=[]
experience_required=[]

# i have planned to scrap 5 pages so i initated while loop
k=0
while k <= 0:
    # finding  elements by  x path functions
    cn = driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
    jt = driver.find_elements_by_xpath("//div[@class='info fleft']/a[1]")
    jl = driver.find_elements_by_xpath("//li[@class = 'fleft grey-text br2 placeHolderLi location']/span[1]")
    er = driver.find_elements_by_xpath("//li[@class = 'fleft grey-text br2 placeHolderLi experience']/span[1]")
    # here i found the next page button by x path functions 
    a = driver.find_element_by_xpath("/html/body/div/div[3]/div[2]/section[2]/div[3]/div/a[2]")
    
    # using for loop to get stored data and extracting text from it
    for i in cn:
        company_name.append(i.text)
        
        
    for j in jt:
        job_title.append(j.text)  
    
    
    
    for l in jl:
        job_location.append(l.text)
        
        
    for m in er:
        experience_required.append(m.text) 
            
    # finally i am simulating a click on next page and whole loop continues again      
    a.click()
    time.sleep(2)
    k +=1

print(f'the company name scrapped are {len(company_name)},the job title scrapped are {len(job_title)},the job locaiton scrapped are {len(job_location)},the experience required scrapped are {len(experience_required)}')

# storing in data frame
df = pd.DataFrame()
df["Company Name"]=company_name
df["Job Title"] = job_title
df["Job Location"]=job_location
df["Experience Required"] = experience_required
df
# Out:
# the company name scrapped are 20,the job title scrapped are 20,the job locaiton scrapped are 20,the experience required scrapped are 20
#                           Company Name  \
# 0                              Walmart
# 1                              Walmart
# 2             Ericsson Global Services
# 3                           Truecaller
# 4        Infineon Technologies Pvt Ltd
# 5                                  IBM
# 6                              Walmart
# 7                                Paytm
# 8                   Schneider Electric
# 9                                  IBM
# 10                  Schneider Electric
# 11            Ericsson Global Services
# 12                   Applied Materials
# 13  Ashkom Media India Private Limited
# 14                ApicalGo Consultancy
# 15                       Serving Skill
# 16                               Groww
# 17                                PayU
# 18                               Gojek
# ...

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# %%
# initating the chrome web driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# %%
# getting to the url
driver.get("https://www.naukri.com/")

# %%
# finding the designation field by absolute xpath
designation = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[1]/div/div/div/input")
# sending the string Data analyst to designaiton field
designation.send_keys("Data Scientist")

# %%
# finding the Search button by Absolute x path
search = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search.click()
# implicit wait for loading the webpage
time.sleep(2)

# %%
# finding the first location filter and clicking it
fil1= driver.find_element_by_xpath("//span[@title='Delhi / NCR']")
fil1.click()
time.sleep(2)

# %%
#finding the second salary filter and clicking it
fil2 = driver.find_element_by_xpath("//span[@title='0-3 Lakhs']")
fil2.click()
time.sleep(2)

# %%
# creating a empty list for all titles to be scrapped
company_name=[]
job_title = []
job_location=[]
experience_required=[]

# i have planned to scrap 5 pages so i initated while loop
k=0

while k <= 0:
    # here i found the next page button by x path functions 
    a = driver.find_element_by_xpath("/html/body/div/div[3]/div[2]/section[2]/div[3]/div/a[2]")
    a.click()
    time.sleep(5)
    # finding  elements by  x path functions
    cn = driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
    jt = driver.find_elements_by_xpath("//div[@class='info fleft']/a[1]")
    jl = driver.find_elements_by_xpath("//li[@class = 'fleft grey-text br2 placeHolderLi location']/span[1]")
    er = driver.find_elements_by_xpath("//li[@class = 'fleft grey-text br2 placeHolderLi experience']/span[1]")
    
    # using for loop to get stored data and extracting text from it
    for i in cn:
        company_name.append(i.text)
        
        
    for j in jt:
        job_title.append(j.text)  
    
    
    
    for l in jl:
        job_location.append(l.text)
        
        
    for m in er:
        experience_required.append(m.text) 
        
    time.sleep(2)
    k +=1

print(f'the company name scrapped are {len(company_name)},the job title scrapped are {len(job_title)},the job locaiton scrapped are {len(job_location)},the experience required scrapped are {len(experience_required)}')

# storing in data frame
df = pd.DataFrame()
df["Company Name"]=company_name
df["Job Title"] = job_title
df["Job Location"]=job_location
df["Experience Required"] = experience_required
df
# Out:
# the company name scrapped are 20,the job title scrapped are 20,the job locaiton scrapped are 20,the experience required scrapped are 20
#                                          Company Name  \
# 0                                Protiviti Consulting
# 1                      NOTUS SERVICES PRIVATE LIMITED
# 2                                             Grofers
# 3                                     Coalition India
# 4                                     Coalition India
# 5                                     Hike Consultant
# 6                                 Maruti Suzuki India
# 7                             Talent City Consultants
# 8                 Incuspaze Solutions Private Limited
# 9                                        Diverse Lynx
# 10                           Harappa Learning Pvt Ltd
# 11                                            Impetus
# 12                                           Quantsys
# 13  AGILITY HUMAN RESOURCE MANAGEMENT SERVICES PRI...
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# %%
# initating the chrome web driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# %%
# getting to the url
driver.get("https://www.flipkart.com/")
time.sleep(2)
# we get login page sometimes so in order to close it
try:
    xmark = driver.find_element_by_xpath("/html/body/div[2]/div/div/button")
    xmark.click()
    
except:
    pass

time.sleep(2)
# finding the search field by absolute xpath
designation = driver.find_element_by_xpath("/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

# sending the string sunglasses to search field
designation.send_keys("sunglasses")

# now searching search button by relative xpath and clicking it
search = driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search.click()
time.sleep(3)

# %%
brand = []
description=[]
price=[]

# %%
# using while loop for getting data from 3 pages
# using for loop to get text values from it
i = 0
x=0
while i <=2:
    
# finding the elements by class name
    brand_name = driver.find_elements_by_class_name("_2WkVRV")
    des = driver.find_elements_by_class_name("IRpwTa")
    pri = driver.find_elements_by_class_name("_3bPFwb")
    ne = driver.find_element_by_class_name("_1LKTO3")
    nee= driver.find_elements_by_xpath("//a[@class='_1LKTO3']")


    
    for b in brand_name:
        brand.append(b.text)
    
    
    

    for c in des:
        description.append(c.text)



    for d in pri:
        price.append(d.text.strip().split("₹")[1])
        
# finally i am simulating a click on next page and whole loop continues again    
    if x ==0:
        ne.click()
        
        
    else:
        nee[1].click()
        
        
    time.sleep(3)
    i +=1
    x=1

    
    
print(f'the brand name scrapped are {len(brand)},the description scrapped are {len(description)},the price scrapped are {len(price)}')

# storing in data frame
df = pd.DataFrame()
df["Brand Name"]=brand
df["Description"] = description
df["Price"]= price
df
# Out:
# the brand name scrapped are 120,the description scrapped are 120,the price scrapped are 120
#          Brand Name                                        Description  Price
# 0       john jacobs           UV Protection Clubmaster Sunglasses (47)  3,460
# 1    ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...    354
# 2          Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    597
# 3          Fastrack   UV Protection Rectangular Sunglasses (Free Size)    589
# 4            PIRASO              UV Protection Aviator Sunglasses (54)    199
# ..              ...                                                ...    ...
# 115   VINCENT CHASE                UV Protection Round Sunglasses (47)    599
# 116          AISLIN  UV Protection Butterfly, Retro Square Sunglass...    448
# 117            hipe  UV Protection, Gradient, Mirrored, Riding Glas...    193
# 118  ROZZETTA CRAFT     UV Protection Spectacle Sunglasses (Free Size)    329
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# %%
# initating the chrome web driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")
# getting to the url
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-%20earpods-power-%20adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKC%20TSVZAXUHGREPBFGI&marketplace")
time.sleep(2)
# finding the all review button
rev = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div/div/div[5]/div/a/div/span")
rev.click()
time.sleep(4)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

# %%
rating=[]
review_summary=[]
full_review=[]

# %%
# using while loop for getting data from 3 pages
# using for loop to get text values from it

i = 0
x = 0

while i <=10:
    ra = driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']")
    re = driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
    fr = driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
    ne = driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    
    
    for a in ra:
        rat=a.find_element_by_class_name("row")
        rating.append(a.text[0])
        


    for b in re:
        review_summary.append(b.text) 
        
        
    for c in fr:
        full_review.append(c.text.strip()) 
        
        
        
    time.sleep(3)    
        
        
        
        
# finally i am simulating a click on next page and whole loop continues again             
    ne[-1].click()
        

    
  
    time.sleep(3)
    
    i +=1
    x=1
 
  
    
print(f'the rating scrapped are {len(rating)},the review summary scrapped are {len(review_summary)},the full review scrapped  are {len(full_review)}')        
    

    
# storing in data frame
df = pd.DataFrame()
df["Rating"]=rating
df["Review Summary"] = review_summary
df["Full Review"]= full_review
df
# Out:
# the rating scrapped are 110,the review summary scrapped are 110,the full review scrapped  are 110
#     Rating       Review Summary  \
# 0        5            Brilliant
# 1        5       Simply awesome
# 2        5  Best in the market!
# 3        5     Perfect product!
# 4        5            Fabulous!
# ..     ...                  ...
# 105      5     Perfect product!
# 106      5              Awesome
# 107      4      Value-for-money
# 108      1            Worthless
# 109      5               Super!
#
#                                            Full Review
# 0    The Best Phone for the Money\n\nThe iPhone 11 ...
# 1    Really satisfied with the Product I received.....
# 2    Great iPhone very snappy experience as apple k...
# 3    Amazing phone with great cameras and better ba...
# 4    This is my first iOS phone. I am very happy wi...
# ..                                                 ...
# 105  Worth the money’ starting first from its perfo...
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# initating the chrome web driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# getting to the url
driver.get("https://www.flipkart.com/")
time.sleep(2)
# we get login page sometimes so in order to close it
try:
    xmark = driver.find_element_by_xpath("/html/body/div[2]/div/div/button")
    xmark.click()
    
except:
    pass

time.sleep(2)
# finding the search field by absolute xpath
designation = driver.find_element_by_xpath("/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

# sending the string sunglasses to search field
designation.send_keys("sneakers")

# now searching search button by relative xpath and clicking it
search = driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search.click()
time.sleep(3)


brand = []
description=[]
price=[]

# using while loop for getting data from 3 pages
# using for loop to get text values from it
i = 0
x=0
while i <=2:
    
# finding the elements by class name
    brand_name = driver.find_elements_by_class_name("_2WkVRV")
    des = driver.find_elements_by_class_name("IRpwTa")
    pri = driver.find_elements_by_class_name("_3bPFwb")
    ne = driver.find_element_by_class_name("_1LKTO3")
    nee= driver.find_elements_by_xpath("//a[@class='_1LKTO3']")


    
    for b in brand_name:
        brand.append(b.text)
    
    
    

    for c in des:
        description.append(c.text)



    for d in pri:
        price.append(d.text.strip().split("₹")[1])
        
# finally i am simulating a click on next page and whole loop continues again    
    if x ==0:
        ne.click()
        
        
    else:
        nee[1].click()
        
        
    time.sleep(3)
    i +=1
    x=1

    
    
print(f'the brand name scrapped are {len(brand)},the description scrapped are {len(description)},the price scrapped are {len(price)}')

# storing in data frame
df = pd.DataFrame()
df["Brand Name"]=brand
df["Description"] = description
df["Price"]= price
df
# Out:
# the brand name scrapped are 120,the description scrapped are 120,the price scrapped are 120
#                 Brand Name                                        Description  \
# 0                   T-ROCK  Stylish White Casual Sneakers shoes Men and Bo...
# 1                   SHELBY  Casual Sneakers Lightweight Shoes for Men and ...
# 2               D-SNEAKERZ  Casual , Partywear Sneakers Shoes For Men's An...
# 3                 URBANBOX                          Sneakers Sneakers For Men
# 4                   corsac        STYLISH MENS BLACK SNEAKER Sneakers For Men
# ..                     ...                                                ...
# 115                Dizzler                                   Sneakers For Men
# 116                 T-ROCK  Stylish White Casual Sneakers shoes Men and Bo...
# 117  HRX by Hrithik Roshan                                   Sneakers For Men
# 118                  BIRDE  Stylish Comfortable Lightweight, Breathable Ca...
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# %%
# initating the chrome web driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# getting to the url
driver.get("https://www.myntra.com/shoes")
time.sleep(3)

# %%
# finding and clicking on filter using class name
fil=driver.find_elements_by_class_name("common-checkboxIndicator")
fil[16].click()
time.sleep(5)
fil[19].click()
time.sleep(5)

# %%
# creating a empty list 
brand=[]
description=[]
price=[]

# %%
i = 0
while i <=1:

    br=driver.find_elements_by_class_name("product-brand")
    des = driver.find_elements_by_class_name("product-product")
    pr = driver.find_elements_by_class_name("product-price")
    next=driver.find_element_by_class_name("pagination-next")


    for a in br:
        brand.append(a.text)
    
    
    for b in des:
        description.append(b.text)   
    
    for c in pr:
        price.append(c.text.strip().split("Rs")[1])
    
    
    next.click()
    time.sleep(5)
    
    i+=1
    
    
    
print(f'the brand name scrapped are {len(brand)},the description scrapped are {len(description)},the price scrapped are {len(price)}')    

# storing in data frame
df = pd.DataFrame()
df["Brand Name"]=brand
df["Description"] = description
df["Price"]= price
df
# Out:
# the brand name scrapped are 100,the description scrapped are 100,the price scrapped are 100
#      Brand Name                     Description    Price
# 0          ALDO       Men Leather Driving Shoes  . 12999
# 1          ALDO                    Men Sneakers   . 9999
# 2      Skechers      Men Max Cushioning Running   . 8099
# 3          ALDO            Men Printed Sneakers   . 9099
# 4          ALDO       Men Woven Design Sneakers  . 13999
# ..          ...                             ...      ...
# 95  RARE RABBIT    Men Textured Leather Loafers   . 7699
# 96     DAVINCHI     Men Formal Leather Slip-Ons   . 8990
# 97     DAVINCHI             Solid Slip On Shoes   . 7990
# 98     Columbia  PEAKFREAK OUTDRY Trekking Shoe   . 9999
# 99     DAVINCHI                    Ustraa black   . 8990
#
# [100 rows x 3 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# %%
# initating the chrome web driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# getting to the url
driver.get("https://www.amazon.in/")
time.sleep(5)

# %%
# sending key laptop to search field
text=driver.find_element_by_xpath("//*[@id='twotabsearchtextbox']")
text.send_keys("Laptop")
# clicking on search button
search=driver.find_element_by_xpath("//*[@id='nav-search-submit-button']")
search.click()

# %%
# clicking the filter i7
fi1=driver.find_element_by_xpath("//*[@id='p_n_feature_thirteen_browse-bin/12598163031']/span/a")
fi1.click()
time.sleep(5)

# %%
# finding the elements using x path 
# using list comprehension getting values and converting to text and stroing them
tr=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
title=[d.text for d in tr]
pr=driver.find_elements_by_xpath("//span[@class='a-price']")
price=[k.text for k in pr]

# %%
# storing in data frame
df = pd.DataFrame()
df["Title"]=title
df["Price"] = price
df
# Out:
#                                                 Title      Price
# 0   Samsung Galaxy Book2 Pro 360 Intel 12th Gen i7...  ₹1,29,990
# 1   Samsung Galaxy Book2 360 Intel 12th Gen i7 Evo...  ₹1,05,990
# 2   ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...    ₹57,490
# 3   HP Pavilion 14, 11th Gen Intel Core i7-16GB RA...    ₹86,990
# 4   LG Gram 16 inches Intel Evo 11th Gen Core i7 U...    ₹89,611
# 5   Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....    ₹86,990
# 6   ASUS TUF Gaming F15 (2021), 15.6" (39.62 cms) ...    ₹89,990
# 7   Fujitsu UH-X 11th Gen Intel Core i7 13.3” FHD ...    ₹84,590
# 8   LG Gram Intel Evo 11th Gen Core i7 17 inches U...    ₹93,999
# 9   Samsung Galaxy Book2 Pro Intel 12th Gen i7 Evo...  ₹1,14,990
# 10  HP Pavilion x360 11th Gen Intel Core i7 14 inc...    ₹86,990
# 11  Lenovo IdeaPad Gaming 3 Intel Core i7 10th Gen...    ₹68,990
# 12  Microsoft Surface Studio 14.4 inches Touchscre...  ₹3,73,999
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# %%
# initating the chrome web driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# getting to the url
driver.get("https://www.ambitionbox.com/")
time.sleep(5)

# %%
# sending key laptop to search field
j=driver.find_element_by_xpath("//a[@class='link jobs']")
j.click()

# %%
# sending key Datas scientist to search fielda
se=driver.find_element_by_xpath("//input[@type='search']")
se.send_keys("Data Scientist")
# click on search button
sea=driver.find_element_by_xpath("//span[@class='ctas-btn-medium']")
sea.click()
time.sleep(5)

# %%
# clicking the drop down
fi=driver.find_elements_by_xpath("//i[@class='icon-chevron-right']")
fi[1].click()
time.sleep(2)
# typing noida in search
fii=driver.find_element_by_xpath("//input[@placeholder='Search locations']")
fii.send_keys("noida")
time.sleep(2)
# selecting noida
fiii=driver.find_element_by_xpath("//label[@for='location_Noida']")
fiii.click()
time.sleep(2)

# %%
# finding the company name rating and no of days bu relative xpath and iterating them to seperate text
cn=driver.find_elements_by_xpath("//p[@class='company body-medium']")
company_name=[a.text for a in cn]

ra=driver.find_elements_by_xpath("//span[@class='body-small']")
rating=[b.text for b in ra]

nod = driver.find_elements_by_xpath("//span[@class='body-small-l']")

no_of_days = [c.text.strip().split('v')[0] for c in nod]

i = 0
while i <=9:
    no_of_days.remove("")
    i +=1

# %%
# storing in data frame
df = pd.DataFrame()
df["Company Name"]=company_name
df["Rating"] = rating
df["No Of Days"] = no_of_days
df
# Out:
#                         Company Name Rating No Of Days
# 0      GENPACT India Private Limited    4.0     5d ago
# 1                  Tech Mahindra Ltd    3.7    19d ago
# 2      GENPACT India Private Limited    4.0    22d ago
# 3                   HCL Technologies    3.8    26d ago
# 4                              Zyoin    4.1     4d ago
# 5  Newgen Software Technologies Ltd.    3.5     6d ago
# 6         Pitney Bowes India Pvt Ltd    4.2   1mon ago
# 7                  JK Technosoft Ltd    3.6    15d ago
# 8  Microsoft India (R and D) Pvt Ltd    4.3   2mon ago
# 9      GENPACT India Private Limited    4.0    3hr ago

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing required libraries
import pandas as pd
import warnings
import time
warnings.filterwarnings("ignore")
from selenium import webdriver

# initating the chrome web driver
driver = webdriver.Chrome("D:\Web Scrapper\chromedriver.exe")

# getting to the url
driver.get("https://www.ambitionbox.com/")
time.sleep(5)

# clicking on salaries
j=driver.find_element_by_xpath("//a[@class='link salaries']")
j.click()

# sending key Datas scientist to search field
se=driver.find_element_by_xpath("//input[@type='searchbox']")
se.send_keys("Data Scientist")
time.sleep(3)

# clicking the data scientist option
jj=driver.find_element_by_xpath("//p[@class='tt_text']")
jj.click()
time.sleep(3)

# %%
# finding the name and other data by relative x path and iterating in forloop for seperating text
na=driver.find_elements_by_xpath("//div[@class='name']")
name=[b.text.split("\n")[0] for b in na]

exp=driver.find_elements_by_xpath("//div[@class='salaries sbold-list-header']")
expierence=[c.text.split("\n")[2] for c in exp]

mini=driver.find_elements_by_xpath("//div[@class='result-col salary-range']")
minimum=[d.text.split("\n")[1] for d in mini]

maxi=driver.find_elements_by_xpath("//div[@class='result-col salary-range']")
maximum=[e.text.split("\n")[2] for e in maxi]

avg=driver.find_elements_by_xpath("//div[@class='result-col salary-range']")
average=[f.text.split("\n")[0] for f in avg]

# %%
# storing in data frame
df = pd.DataFrame()
df["Company Name"]= name
df["Minimum Salary"] = minimum
df["Maximum Salary"] = maximum
df["Average Salary"] = average
df
# Out:
#                Company Name Minimum Salary Maximum Salary Average Salary
# 0                   Walmart        ₹ 25.0L        ₹ 35.0L        ₹ 29.7L
# 1                  Ab Inbev        ₹ 15.0L        ₹ 25.5L        ₹ 20.5L
# 2              Reliance Jio         ₹ 5.6L        ₹ 26.2L        ₹ 18.9L
# 3                        ZS         ₹ 9.8L        ₹ 20.0L        ₹ 15.9L
# 4                     Optum        ₹ 11.0L        ₹ 22.4L        ₹ 15.4L
# 5         Fractal Analytics         ₹ 9.5L        ₹ 22.0L        ₹ 15.1L
# 6           Tiger Analytics         ₹ 9.0L        ₹ 20.0L        ₹ 14.8L
# 7              UnitedHealth         ₹ 8.3L        ₹ 20.5L        ₹ 14.0L
# 8                   Verizon        ₹ 10.0L        ₹ 21.0L        ₹ 12.7L
# 9  Ganit Business Solutions         ₹ 8.5L        ₹ 15.0L        ₹ 12.4L
