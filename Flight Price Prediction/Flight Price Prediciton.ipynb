# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %%
# importing requried libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("Combined.xlsx")
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
df.head()
# Out:
#    Unnamed: 0       Date Airline Name Departure   Source   Duration      Stop  \
# 0           0 2022-07-17       IndiGo  08:40:00  Chennai       01 h  Non stop
# 1           1 2022-07-17       IndiGo  09:45:00  Chennai  01 h 10 m  Non stop
# 2           2 2022-07-17    Air India  13:30:00  Chennai  01 h 05 m  Non stop
# 3           3 2022-07-17       IndiGo  14:35:00  Chennai       01 h  Non stop
# 4           4 2022-07-17       IndiGo  16:15:00  Chennai       01 h  Non stop
#
#   Destination   Arrival      Price
# 0  Coimbatore  09:40:00  â‚¹ 3,523
# 1  Coimbatore  10:55:00  â‚¹ 3,523
# 2  Coimbatore  14:35:00  â‚¹ 3,523
# 3  Coimbatore  15:35:00  â‚¹ 3,523
# 4  Coimbatore  17:15:00  â‚¹ 3,523

# %%
df.tail()
# Out:
#       Unnamed: 0       Date Airline Name Departure   Source   Duration  \
# 9905        4325 2023-02-26       IndiGo  06:25:00  Chennai  04 h 50 m
# 9906        4326 2023-02-26     Go First  05:00:00  Chennai  01 h 50 m
# 9907        4327 2023-02-26     Go First  13:45:00  Chennai  01 h 55 m
# 9908        4328 2023-02-26     Go First  15:15:00  Chennai  06 h 10 m
# 9909        4329 2023-02-26     Go First  15:15:00  Chennai  10 h 45 m
#
#                       Stop Destination   Arrival       Price
# 9905    1 stop via Madurai      Mumbai  11:15:00  â‚¹ 11,661
# 9906              Non stop      Mumbai  06:50:00  â‚¹ 12,236
# 9907              Non stop      Mumbai  15:40:00  â‚¹ 12,236
# 9908  1 stop via Ahmedabad      Mumbai  21:25:00  â‚¹ 19,245
# 9909  1 stop via Ahmedabad      Mumbai  02:00:00  â‚¹ 19,245

# %%
df.shape
# Out:
# (9910, 10)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Airline Name', 'Departure', 'Source', 'Duration',
#        'Stop', 'Destination', 'Arrival', 'Price'],
#       dtype='object')

# %% [markdown]
# # Observation

# %% [markdown]
# this dataset has 9910 rows and 10 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9910 entries, 0 to 9909
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    9910 non-null   int64
#  1   Date          9910 non-null   datetime64[ns]
#  2   Airline Name  9910 non-null   object
#  3   Departure     9910 non-null   object
#  4   Source        9910 non-null   object
#  5   Duration      9910 non-null   object
#  6   Stop          9910 non-null   object
#  7   Destination   9910 non-null   object
#  8   Arrival       9910 non-null   object
#  9   Price         9910 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 774.3+ KB

# %% [markdown]
# # Observation

# %% [markdown]
# We have Object and Integer data

# %%
df.describe()
# Out:
#         Unnamed: 0
# count  9910.000000
# mean   2170.450454
# std    1389.714902
# min       0.000000
# 25%     887.000000
# 50%    2125.500000
# 75%    3364.000000
# max    4876.000000

# %%
df.nunique()
# Out:
# Unnamed: 0      4877
# Date             226
# Airline Name       8
# Departure        103
# Source             1
# Duration          80
# Stop              25
# Destination        3
# Arrival          119
# Price            260
# dtype: int64

# %%
df["Destination"].unique()
# Out:
# array(['Coimbatore', 'New Delhi', 'Mumbai'], dtype=object)

# %%
df["Source"].unique()
# Out:
# array(['Chennai'], dtype=object)

# %%
df["Airline Name"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Vistara', 'Go First', 'SpiceJet',
#        'AirAsia', 'IndiGo, Go First', 'IndiGo, AirAsia'], dtype=object)

# %% [markdown]
# # null value check

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0      0
# Date            0
# Airline Name    0
# Departure       0
# Source          0
# Duration        0
# Stop            0
# Destination     0
# Arrival         0
# Price           0
# dtype: int64

# %% [markdown]
# # observation

# %% [markdown]
# there are no null values

# %% [markdown]
# # univariate analysis

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['Airline Name'])
# Out:
# <AxesSubplot:xlabel='Airline Name', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# IndiGo Flights count is higher

# %%
sns.countplot(df['Source'])
# Out:
# <AxesSubplot:xlabel='Source', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# Flights start Delhi

# %%
sns.countplot(df['Destination'])
# Out:
# <AxesSubplot:xlabel='Destination', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# New Delhi Has higher no of flights compared to other destinations

# %%
plt.figure(figsize=(50,20))
sns.countplot(df['Stop'])
# Out:
# <AxesSubplot:xlabel='Stop', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# non stop are higher compared to others

# %% [markdown]
# # Bivariate Analysis

# %%
df["Price"]=df["Price"].str.replace("â‚¹","").str.replace(",","").str.strip().astype("int")

# %%
plt.figure(figsize=(30,10))
sns.barplot(df['Airline Name'],df['Price'])
# Out:
# <AxesSubplot:xlabel='Airline Name', ylabel='Price'>

# %%
plt.figure(figsize=(30,10))
sns.scatterplot(df['Airline Name'],df['Price'])
# Out:
# <AxesSubplot:xlabel='Airline Name', ylabel='Price'>

# %% [markdown]
# # Observation

# %% [markdown]
# GoFirst , SpiceJet Price is higher compared to others

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['Source'],df['Price'])

# %% [markdown]
# # Observation

# %% [markdown]
# Flights Price can go up to 25000 from chennai

# %%
plt.figure(figsize=(40,20))
sns.scatterplot(df['Stop'],df['Price'])
# Out:
# <AxesSubplot:xlabel='Stop', ylabel='Price'>

# %%
plt.figure(figsize=(50,10))
sns.barplot(df['Stop'],df['Price'])
# Out:
# <AxesSubplot:xlabel='Stop', ylabel='Price'>

# %% [markdown]
# # observations

# %% [markdown]
# No stop pirce is lower compared to all

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['Destination'],df['Price'])
# Out:
# <AxesSubplot:xlabel='Destination', ylabel='Price'>

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df['Destination'],df['Price'])
# Out:
# <AxesSubplot:xlabel='Destination', ylabel='Price'>

# %% [markdown]
# # Observation

# %% [markdown]
# Flights arrival at New delhi is higher price compared to others

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df['Date'],df['Price'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Price'>

# %% [markdown]
# # Observation

# %% [markdown]
# The price of flight is higher when we book at last minute we can see for july and august month price is so high

# %% [markdown]
# The price is lower for september and october

# %% [markdown]
# then again for advance booking at very large timeinterval the price is higher

# %%
dft = pd.DataFrame()
dft["time"] = pd.to_datetime(df["Departure"],format="%H:%M:%S").dt.hour
dft["Price"]=df["Price"].str.replace("â‚¹","").str.replace(",","").str.strip().astype("int")

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
sns.lineplot(dft["time"],dft["Price"])
plt.xticks(np.arange(2, 24, 1))
# Out:
# ([<matplotlib.axis.XTick at 0x284e69e8220>,
#   <matplotlib.axis.XTick at 0x284e69e81f0>,
#   <matplotlib.axis.XTick at 0x284e6c3a640>,
#   <matplotlib.axis.XTick at 0x284e6c68370>,
#   <matplotlib.axis.XTick at 0x284e6c583d0>,
#   <matplotlib.axis.XTick at 0x284e6c588e0>,
#   <matplotlib.axis.XTick at 0x284e6c58a60>,
#   <matplotlib.axis.XTick at 0x284e6c58d60>,
#   <matplotlib.axis.XTick at 0x284e6c562b0>,
#   <matplotlib.axis.XTick at 0x284e6c567c0>,
#   <matplotlib.axis.XTick at 0x284e6c56cd0>,
#   <matplotlib.axis.XTick at 0x284e6c68880>,
#   <matplotlib.axis.XTick at 0x284e6c3a760>,
#   <matplotlib.axis.XTick at 0x284e6c3d0d0>,
#   <matplotlib.axis.XTick at 0x284e6c3d5e0>,
#   <matplotlib.axis.XTick at 0x284e6c3daf0>,
#   <matplotlib.axis.XTick at 0x284e6ae8040>,
#   <matplotlib.axis.XTick at 0x284e6ae8550>,
#   <matplotlib.axis.XTick at 0x284e6c3d310>,
#   <matplotlib.axis.XTick at 0x284e6c59a90>,
#   <matplotlib.axis.XTick at 0x284e6c56d30>,
#   <matplotlib.axis.XTick at 0x284e6ae8820>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(dft["time"],dft['Price'])
plt.xticks(np.arange(2, 24, 1))
# Out:
# ([<matplotlib.axis.XTick at 0x284e6ac29a0>,
#   <matplotlib.axis.XTick at 0x284e6ac2970>,
#   <matplotlib.axis.XTick at 0x284e6b9b910>,
#   <matplotlib.axis.XTick at 0x284e6b9bd90>,
#   <matplotlib.axis.XTick at 0x284e6b812e0>,
#   <matplotlib.axis.XTick at 0x284e6b817f0>,
#   <matplotlib.axis.XTick at 0x284e6b81d30>,
#   <matplotlib.axis.XTick at 0x284e6b78280>,
#   <matplotlib.axis.XTick at 0x284e6b81940>,
#   <matplotlib.axis.XTick at 0x284e6b9b940>,
#   <matplotlib.axis.XTick at 0x284e6b788e0>,
#   <matplotlib.axis.XTick at 0x284e6ab04f0>,
#   <matplotlib.axis.XTick at 0x284e6b9b070>,
#   <matplotlib.axis.XTick at 0x284e6ba1e20>,
#   <matplotlib.axis.XTick at 0x284e6b78eb0>,
#   <matplotlib.axis.XTick at 0x284e6b81370>,
#   <matplotlib.axis.XTick at 0x284e6b7aca0>,
#   <matplotlib.axis.XTick at 0x284e6bc41f0>,
#   <matplotlib.axis.XTick at 0x284e6bc4700>,
#   <matplotlib.axis.XTick at 0x284e6bc4c10>,
#   <matplotlib.axis.XTick at 0x284e6bcc160>,
#   <matplotlib.axis.XTick at 0x284e6bcc670>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.pairplot(df)

# %% [markdown]
# # Encoding

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# Date            datetime64[ns]
# Airline Name            object
# Departure               object
# Source                  object
# Duration                object
# Stop                    object
# Destination             object
# Arrival                 object
# Price                   object
# dtype: object

# %% [markdown]
# # Observation

# %% [markdown]
# now i need to encode categorical data

# %%
df["Price"]=df["Price"].str.replace("â‚¹","").str.replace(",","").str.strip().astype("int")

# %% [markdown]
# # Using pd.get_dummies as data are not ordinal in nature

# %%
df.head()
# Out:
#    Unnamed: 0       Date Airline Name Departure   Source   Duration      Stop  \
# 0           0 2022-07-17       IndiGo  08:40:00  Chennai       01 h  Non stop
# 1           1 2022-07-17       IndiGo  09:45:00  Chennai  01 h 10 m  Non stop
# 2           2 2022-07-17    Air India  13:30:00  Chennai  01 h 05 m  Non stop
# 3           3 2022-07-17       IndiGo  14:35:00  Chennai       01 h  Non stop
# 4           4 2022-07-17       IndiGo  16:15:00  Chennai       01 h  Non stop
#
#   Destination   Arrival  Price
# 0  Coimbatore  09:40:00   3523
# 1  Coimbatore  10:55:00   3523
# 2  Coimbatore  14:35:00   3523
# 3  Coimbatore  15:35:00   3523
# 4  Coimbatore  17:15:00   3523

# %%
a = pd.get_dummies(df["Airline Name"])
b = pd.get_dummies(df["Destination"],prefix="destination")
c = pd.get_dummies(df["Stop"]).astype(int)
d = pd.get_dummies(df["Source"])

# %%
from datetime import time

# %%
df["Journey_day"] = df["Date"].dt.day

# %%
df["Journey_month"] = df["Date"].dt.month

# %%
df["Journey_year"] = df["Date"].dt.year

# %%
df["Dep_hours"] = pd.to_datetime(df["Departure"],format="%H:%M:%S").dt.hour

# %%
df["Dep_minutes"] = pd.to_datetime(df["Departure"],format="%H:%M:%S").dt.minute

# %%
df["Arrival_hours"] = pd.to_datetime(df["Arrival"],format="%H:%M:%S").dt.hour

# %%
df["Arrival_minutes"] = pd.to_datetime(df["Arrival"],format="%H:%M:%S").dt.minute

# %% [markdown]
# # Seperating day month  , hours and minutes

# %%
dur = list(df["Duration"])

for i in range(len(dur)):
    if len(dur[i].split()) == 2:   
        if "h" in dur[i]:
            dur[i] = dur[i].strip() + " 0m"  
        else:
            dur[i] = "0h " + dur[i]

# %%
duration_hours = []
duration_mins = []

# %%
for i in range(len(dur)):
    duration_hours.append(int(dur[i].split(sep = "h")[0]))  
    duration_mins.append(int(dur[i].split(sep = "m")[0].split()[-1]))

# %%
df["Duration_hours"] = duration_hours
df["Duration_minutes"] = duration_mins

# %% [markdown]
# # Observation

# %%
df.head()
# Out:
#    Price  Journey_day  Journey_month  Journey_year  Dep_hours  Dep_minutes  \
# 0   3523           17              7          2022          8           40
# 1   3523           17              7          2022          9           45
# 2   3523           17              7          2022         13           30
# 3   3523           17              7          2022         14           35
# 4   3523           17              7          2022         16           15
#
#    Arrival_hours  Arrival_minutes  Duration_hours  Duration_minutes
# 0              9               40               1                 0
# 1             10               55               1                10
# 2             14               35               1                 5
# 3             15               35               1                 0
# 4             17               15               1                 0

# %%
df.drop(["Date","Departure","Arrival","Duration","Airline Name","Source","Destination","Unnamed: 0","Stop"],inplace=True,axis=1)

# %%
# joining dummies to dataframe
df_new=df.join(a).join(b).join(c).join(d)

# %%
df_new.dtypes
# Out:
# Price                          int32
# Journey_day                    int64
# Journey_month                  int64
# Journey_year                   int64
# Dep_hours                      int64
# Dep_minutes                    int64
# Arrival_hours                  int64
# Arrival_minutes                int64
# Duration_hours                 int64
# Duration_minutes               int64
# Air India                      uint8
# AirAsia                        uint8
# Go First                       uint8
# IndiGo                         uint8
# IndiGo, AirAsia                uint8
# IndiGo, Go First               uint8
# SpiceJet                       uint8
# Vistara                        uint8
# destination_Coimbatore         uint8
# destination_Mumbai             uint8
# destination_New Delhi          uint8
# 1 stop via Ahmedabad           int32
# 1 stop via Bengaluru           int32
# 1 stop via Bhopal              int32
# 1 stop via Coimbatore          int32
# 1 stop via Goa                 int32
# 1 stop via Guwahati            int32
# 1 stop via Hyderabad           int32
# 1 stop via Indore              int32
# 1 stop via Jabalpur            int32
# 1 stop via Jaipur              int32
# 1 stop via Kochi               int32
# 1 stop via Kozhikode           int32
# 1 stop via Lucknow             int32
# 1 stop via Madurai             int32
# 1 stop via Mumbai              int32
# 1 stop via Nagpur              int32
# 1 stop via Patna               int32
# 1 stop via Pune                int32
# 1 stop via Raipur              int32
# 1 stop via Shirdi              int32
# 1 stop via Visakhapatnam       int32
# 2 stop via Bengaluru,Shirdi    int32
# 2 stop via Mumbai,Bengaluru    int32
# 2 stop via New Delhi,Mumbai    int32
# Non stop                       int32
# Chennai                        uint8
# dtype: object

# %% [markdown]
# # Observation

# %% [markdown]
# we have succesfully converted all object data to numeric data

# %% [markdown]
# # Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(df_new.values,a) for a in range(46)]
vif["Feature names"] = df_new.columns
vif.sort_values(by="VIF",ascending=False)
# Out:
#          VIF                Feature names
# 23       inf        1 stop via Coimbatore
# 33       inf           1 stop via Madurai
# 25       inf          1 stop via Guwahati
# 26       inf         1 stop via Hyderabad
# 27       inf            1 stop via Indore
# 28       inf          1 stop via Jabalpur
# 29       inf            1 stop via Jaipur
# 30       inf             1 stop via Kochi
# 31       inf         1 stop via Kozhikode
# 32       inf           1 stop via Lucknow
# 34       inf            1 stop via Mumbai
# 44       inf                     Non stop
# 35       inf            1 stop via Nagpur
# 36       inf             1 stop via Patna
# 37       inf              1 stop via Pune
# 38       inf            1 stop via Raipur
# 39       inf            1 stop via Shirdi
# 40       inf     1 stop via Visakhapatnam
# 41       inf  2 stop via Bengaluru,Shirdi
# 42       inf  2 stop via Mumbai,Bengaluru
# 24       inf               1 stop via Goa
# 22       inf            1 stop via Bhopal
# 21       inf         1 stop via Bengaluru
# 15       inf                     SpiceJet
# 9        inf                    Air India
# 10       inf                      AirAsia
# 12       inf                       IndiGo
# 13       inf              IndiGo, AirAsia
# 14       inf             IndiGo, Go First
# 11       inf                     Go First
# 16       inf                      Vistara
# 17       inf       destination_Coimbatore
# 18       inf           destination_Mumbai
# 19       inf        destination_New Delhi
# 20       inf         1 stop via Ahmedabad
# 43       inf  2 stop via New Delhi,Mumbai
# 2   8.683949                 Journey_year
# 1   8.321066                Journey_month
# 7   7.281375               Duration_hours
# 8   1.911583             Duration_minutes
# 5   1.686991                Arrival_hours
# 3   1.618726                    Dep_hours
# 4   1.245321                  Dep_minutes
# 6   1.172278              Arrival_minutes
# 0   1.033667                  Journey_day
# 45  0.000000                      Chennai

# %% [markdown]
# # Observation

# %% [markdown]
# We have mulitcollinearity so i am going to use PCA to Merge all columns to remove Mulitcollinearity

# %% [markdown]
# # PCA

# %%
df_new.drop(["Price"],axis=1,inplace=True)

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(df_new)

# %%
df_new.shape
# Out:
# (9910, 46)

# %%
fig, ax = plt.subplots(figsize=(20,10))
xi = np.arange(1, 47, step=1)
yi = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, yi, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 68, step=1)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=1, color='r', linestyle='-')
plt.text(0.5, 0.85, '100% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %% [markdown]
# # Principal component analysis as no of columns are higher

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=40)
dfi=pca.fit_transform(df_new)

# %%
df_new = pd.DataFrame(dfi)

# %%
df_new.shape
# Out:
# (9910, 40)

# %% [markdown]
# # Multicolinearity Checking

# %% [markdown]
# # variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(df_new.values,a) for a in range(40)]
vif["Feature names"] = df_new.columns
vif.sort_values(by=["VIF"],ascending=False)
# Out:
#     VIF  Feature names
# 35  1.0             35
# 38  1.0             38
# 39  1.0             39
# 10  1.0             10
# 22  1.0             22
# 36  1.0             36
# 37  1.0             37
# 24  1.0             24
# 25  1.0             25
# 8   1.0              8
# 7   1.0              7
# 18  1.0             18
# 1   1.0              1
# 33  1.0             33
# 23  1.0             23
# 32  1.0             32
# 28  1.0             28
# 29  1.0             29
# 21  1.0             21
# 15  1.0             15
# 34  1.0             34
# 17  1.0             17
# 31  1.0             31
# 13  1.0             13
# 11  1.0             11
# 9   1.0              9
# 5   1.0              5
# 4   1.0              4
# 3   1.0              3
# 2   1.0              2
# 30  1.0             30
# 0   1.0              0
# 27  1.0             27
# 26  1.0             26
# 19  1.0             19
# 16  1.0             16
# 14  1.0             14
# 12  1.0             12
# 6   1.0              6
# 20  1.0             20

# %% [markdown]
# # observaiton

# %% [markdown]
# No multicolinearity observed as PCA takes care of multicolinearity

# %%
x_final = df_new
y = df["Price"]

# %% [markdown]
# # model Training starts

# %% [markdown]
# # Importing required libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score,KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge,Lasso,ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %% [markdown]
# # i have write a code block that tests data with models and rank them according to cross val score and accuracy score

# %%
result = pd.DataFrame(columns=["Model Name","Train Score","Test Score","Cross Val Score"])
ela=[]
lin=[]
dec=[]
rid=[]
las=[]
kne=[]
rfr=[]
ada=[]
licol=[ela,lin,dec,rid,las,kne,rfr,ada]

algo = [ElasticNet(),LinearRegression(),DecisionTreeRegressor(),Ridge(),Lasso(),KNeighborsRegressor(),RandomForestRegressor(),AdaBoostRegressor()]
oo= 0    
for v in algo:
    r = 0
    acc = 0
    for i in range(0,60):
        al = v
        train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=i)
        al.fit(train_x,train_y)
        score = al.score(train_x,train_y)
        if score>acc:
            acc = score
            r = i
            
    print(f'the best random state is {r} for {v}')     
        
 
    train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=r)
    al.fit(train_x,train_y)
    trs = al.score(train_x,train_y)
    tss = al.score(test_x,test_y)
    cvs = cross_val_score(al,x_final,y,cv=KFold(5)).mean()   
    licol[oo].insert(0,v)
    licol[oo].insert(1,trs)
    licol[oo].insert(2,tss)
    licol[oo].insert(3,cvs)
    result.loc[oo] = licol[oo]
    oo+=1

final_result = result.sort_values(by=["Cross Val Score","Test Score"],ascending=False)
# Out:
# the best random state is 39 for ElasticNet()
# the best random state is 39 for LinearRegression()
# the best random state is 32 for DecisionTreeRegressor()
# the best random state is 39 for Ridge()
# the best random state is 39 for Lasso()
# the best random state is 44 for KNeighborsRegressor()
# the best random state is 44 for RandomForestRegressor()
# the best random state is 18 for AdaBoostRegressor()

# %%
final_result
# Out:
#                                           Model Name  Train Score  Test Score  \
# 4                                            Lasso()     0.755842    0.658784
# 3                                            Ridge()     0.759318    0.664432
# 6  (DecisionTreeRegressor(max_features='auto', ra...     0.985830    0.743175
# 0                                       ElasticNet()     0.484586    0.410680
# 7  (DecisionTreeRegressor(max_depth=3, random_sta...     0.148908   -0.015018
# 5                              KNeighborsRegressor()     0.875108    0.711916
# 2                            DecisionTreeRegressor()     0.999915    0.830839
# 1                                 LinearRegression()     0.760189    0.660331
#
#    Cross Val Score
# 4     2.366388e-01
# 3     2.213105e-01
# 6     8.238501e-02
# 0     6.430430e-02
# 7    -7.531857e-01
# 5    -7.889693e-01
# 2    -2.878913e+00
# 1    -1.573558e+19

# %%
final_result.loc[4]["Model Name"]
# Out:
# Lasso()

# %% [markdown]
# # running Support vector classifier induvidually as it consumes more memory

# %%
svr = SVR()
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=39)
svr.fit(train_x,train_y)
trs = al.score(train_x,train_y)
tss = al.score(test_x,test_y)
cvs = cross_val_score(svr,x_final,y,cv=KFold(5)).mean()
print(f'the training score is {trs} the testing score is {tss} the cross val score is {cvs} for {v}')

# %% [markdown]
# # Observation

# %% [markdown]
# from all the classifier models Lasso  performed best

# %% [markdown]
# # HyperParameter Tunining

# %%
from sklearn.model_selection import GridSearchCV

# %%
ls =Lasso()
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=39)
parameters = {"alpha":[0.0001,0.001,0.01,0.05,0.1,0.2,0.5,0.8,1],"fit_intercept":[True,False],"copy_X":[True,False],"tol":[0.0001,0.001,0.1,0.5],"warm_start":[True,False]}
from sklearn.model_selection import GridSearchCV
gsv = GridSearchCV(ls,parameters)
gsv.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=Lasso(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2, 0.5,
#                                    0.8, 1],
#                          'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'tol': [0.0001, 0.001, 0.1, 0.5],
#                          'warm_start': [True, False]})

# %%
gsv.best_params_
# Out:
# {'alpha': 0.1,
#  'copy_X': True,
#  'fit_intercept': True,
#  'tol': 0.5,
#  'warm_start': True}

# %% [markdown]
# # using the best parameters got in grid search

# %%
rf = Lasso(alpha=1,copy_X=True,fit_intercept=True,tol=0.5,warm_start=True)
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.15,random_state=16)
rf.fit(train_x,train_y)
trs = rf.score(train_x,train_y)
tss = rf.score(test_x,test_y)
pred = rf.predict(test_x)
cvs = cross_val_score(rf,x_final,y).mean()
print(f'the training score is {trs} the testing score is {tss} the cross val score is {cvs}')
print("Mean Squared Error",mean_squared_error(test_y,pred))
print("Mean Absolute Error", mean_absolute_error(test_y,pred))
print("Root Mean Squared Error", np.sqrt(mean_squared_error(test_y,pred)))
print("R2 Score", r2_score(test_y,pred))
# Out:
# the training score is 0.7383918180828726 the testing score is 0.7268376561335179 the cross val score is 0.26222719334269395
# Mean Squared Error 897621.8656094349
# Mean Absolute Error 553.4692865967716
# Root Mean Squared Error 947.4290821003094
# R2 Score 0.7268376561335179

# %% [markdown]
# # Observation

# %% [markdown]
# # The Training score is 73% , Testing Score 72% and Cross val score is 26%

# %% [markdown]
# # saving the model

# %%
import joblib
joblib.dump(rf,"FlightPricePrediction.pkl")
# Out:
# ['FlightPricePrediction.pkl']
